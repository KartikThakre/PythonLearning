# %%
print("Hello Jupyter in VS Code")
# Out:
# Hello Jupyter in VS Code

# %%
sample_data = { 

"employee_name": ["Alex", "Priya"], 

"hours_worked": [8, 7], 

"tasks_completed": [5, 6] 

} 

print(sample_data)
# Out:
# {'employee_name': ['Alex', 'Priya'], 'hours_worked': [8, 7], 'tasks_completed': [5, 6]}

# %%
sample_data = { 

"employee_name": ["Alex", "Priya"], 

"hours_worked": [8, 7], 

"tasks_completed": [5, 6] 

} 

sample_data
# Out:
# {'employee_name': ['Alex', 'Priya'],
#  'hours_worked': [8, 7],
#  'tasks_completed': [5, 6]}

# %% [markdown]
# # Understanding Jupyter Notebook
#
# Jupyter Notebook is an interactive environment where we can write and run Python code step by step.
# It allows us to combine code, explanations, and output in one place.
#
# It is useful for learning, data analysis, and testing logic quickly without running the entire program.

# %%
print("Analyzing employee timesheet data to calculate productivity...")
# Out:
# Analyzing employee timesheet data to calculate productivity...

# %%
marks = [80, 75, 90, 85]
plt.plot(marks)
plt.title("Student Marks")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 marks = [80, 75, 90, 85]
# ----> 2 plt.plot(marks)
#       3 plt.title("Student Marks")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
marks = [80, 75, 90, 85]
plt.plot(marks)
plt.title("Student Marks")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 marks = [80, 75, 90, 85]
# ----> 2 plt.plot(marks)
#       3 plt.title("Student Marks")
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
marks = [80, 75, 90, 85]
plt.plot(marks) 
plt.title("Student Marks")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 marks = [80, 75, 90, 85]
#       3 plt.plot(marks)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
marks = [80, 75, 90, 85]
plt.plot(marks) 
plt.title("Student Marks")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 marks = [80, 75, 90, 85]
#       3 plt.plot(marks)
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
marks = [80, 75, 90, 85]
plt.plot(marks) 
plt.title("Student Marks")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# ## Use Cases of Jupyter Notebook in My Role
#
# 1. Analyzing API response data before integrating into frontend UI.
# 2. Testing and validating business logic before implementing in React.
# 3. Exploring user behavior or logs data for dashboard features.
# 4. Prototyping AI/ML features before integrating into applications.
# 5. Debugging and experimenting with data transformations.
